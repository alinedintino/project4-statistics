# %% [markdown]
# Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_1samp
import scipy.stats as sp
import math
from scipy.stats import norm
from scipy.stats import t
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt

# %% [markdown]
# Add the data for suicide rates

# %%
suicides=pd.read_csv('../data/master.csv')

# %%
reg=pd.read_csv('reg.csv')

# %% [markdown]
# Add the region data from Deaths in conflict dataset to the suicide dataset that did not have Region info

# %%
suicides=suicides.merge(reg, on='country')
suicides.rename(columns={"region_y": "region"},inplace=True)

# %%
suicides.groupby('year').sum()
# Out:
#       suicides_no  population  suicides/100k pop  HDI for year  \
# year
# 1985        52141   574376092            2835.44       180.912
# 1986        52822   587393552            2934.53         0.000
# 1987        59200   640674852            3052.98         0.000
# 1988        55229   596219458            3002.93         0.000
# 1989        58234   628116991            3293.08         0.000
# 1990        78177   797094521            4043.60       233.424
# 1991        78994   807514315            4027.09         0.000
# 1992        80815   867118941            4018.18         0.000
# 1993        79332   820960923            3871.00         0.000
# 1994        82648   829050360            3956.32         0.000
# 1995        87851   850226367            4476.70       274.092
# 1996        93145   916865147            4774.99         0.000
# 1997        94994   989932364            4825.83         0.000
# 1998        94944  1001134854            4687.27         0.000
# 1999        94303  1011917914            4901.28         0.000
# 2000        95029  1024686423            4562.75       332.880
# 2001        89444   976983902            4816.53         0.000
# 2002        93389  1040019734            4565.59         0.000
# 2003        93364  1052442473            4609.50         0.000
# 2004        85488   974134289            4254.63         0.000
# 2005        82024   960910269            3837.07       327.420
# 2006        86726  1064012859            4292.21         0.000
# 2007        81972  1061207541            3862.01         0.000
# 2008        83921  1059812578            3863.96         0.000
# 2009        88179  1169671867            3892.31         0.000
# 2010        88363  1186805286            4018.77       379.836
# 2011        89401  1186288925            3853.80       362.868
# 2012        88570  1108029645            3736.35       338.808
# 2013        80783  1074172075            3372.64       330.936
# 2014        84758  1090275707            3206.71       322.164
# 2015        73218   994758931            2745.46         0.000
# 2016         9904   100632509             730.43         0.000
#
#       gdp_per_capita ($)
# year
# 1985             1705380
# 1986             1803312
# 1987             2499696
# 1988             2585136
# 1989             2615556
# 1990             3394260
# 1991             3533472
# 1992             3674700
# 1993             3566748
# 1994             3777312
# 1995             4523280
# 1996             4588344
# 1997             4608828
# 1998             4571328
# 1999             4567704
# 2000             4597188
# 2001             4884636
# 2002             4678752
# 2003             5555868
# 2004             6920520
# 2005             7616736
# 2006             8834496
# 2007             9774432
# 2008            10800948
# 2009             9473904
# 2010            10140504
# 2011            10879788
# 2012            10405344
# 2013            10683660
# 2014            10015008
# 2015             7414848
# 2016             1996120

# %%
#suicides.sort_values("country", inplace = True) 
#filter1 = suicides["year"]==2014
#suicides.where(filter1,inplace = True)

# %%
suicides.dropna(how='all',inplace=True)

# %%
suicides.groupby('country').sum()
# Out:
#                         year  suicides_no  population  suicides/100k pop  \
# country
# Albania               527796         1970    62325467             924.76
# Argentina             744000        82219  1035985431            3894.59
# Armenia               596832         1905    77348173             976.21
# Australia             719940        70111   542377786            4677.41
# Azerbaijan            383544         1656   111790300             356.24
# Bahrain               504708          463    16753926             467.24
# Belgium               744000        62761   303302621            7900.50
# Brazil                744000       226613  4856093548            2174.72
# Canada                695652       107561   826052183            4338.72
# Nicaragua             144900         2013    31742633             472.82
# Panama                600540         3483    70265659            1744.06
# Paraguay              648144         4783   124641969            1366.37
# Philippines           360432        21330  1065068179             435.83
# Qatar                 357480          574    21870545             318.15
# Romania               668808        72777   575065963            4171.55
# South Africa          481320         7321   873130762             231.49
# Spain                 744000       100202  1227661095            3509.06
# Sri Lanka             263676        55641   182525626            4658.96
# Sweden                716508        37795   253297131            5247.72
# Thailand              668508       110643  1584800281            2362.67
# Trinidad and Tobago   647352         4039    31243097            4479.51
# Turkey                169008        10131   482640582             199.17
# Ukraine               672192       319950  1286469184            8931.66
# United Arab Emirates  144540          622    36502275              94.89
# United Kingdom        744000       136805  1738767780            2790.92
# Uzbekistan            528348        34803   486422532            2138.17
#
#                       HDI for year  gdp_per_capita ($)
# country
# Albania                     32.304              490788
# Argentina                   93.552             2944044
# Armenia                     66.252              558428
# Australia                   87.624            11799504
# Azerbaijan                  14.988              192984
# Bahrain                     77.244             4545960
# Belgium                    103.284            11928828
# Brazil                      83.388             2266032
# Canada                      95.160            10748844
# Colombia                    80.436             1379736
# Croatia                     75.576             2713238
# Ecuador                     83.304             1222488
# El Salvador                 67.584              734592
# France                     101.832            11333328
# Georgia                     61.308              499788
# Germany                     95.232            10971240
# Guatemala                   62.748              814872
# Guyana                      51.096              502476
# Israel                     102.456             8602668
# Italy                      100.176             9896160
# Jamaica                     50.448              673452
# Kuwait                      85.812             8345700
# Kyrgyzstan                  67.308              224868
# Malta                       94.836             5224524
# Mexico                      85.584             2655504
# Netherlands                106.164            13643004
# Nicaragua                   37.512              146076
# Panama                      71.328             1987956
# Paraguay                    76.560              766512
# Philippines                 23.160              277236
# Qatar                       70.224            12060648
# Romania                     81.516             1600344
# South Africa                54.324             1341480
# Spain                       99.804             7805364
# Sri Lanka                   15.312              119364
# Sweden                      95.760            14806012
# Thailand                    79.980             1193102
# Trinidad and Tobago         60.468             2860608
# Turkey                      45.180             1019280
# Ukraine                     68.496              627492
# United Arab Emirates        19.800             3035664
# United Kingdom             103.620            11869908
# Uzbekistan                  54.600              257712

# %% [markdown]
# Add the data for deaths in conflict

# %%
conflict=pd.read_excel('../data/ged201.xlsx')
conflict.head()
# Out:
#        id               relid  year  active_year code_status  \
# 0  244657  IRQ-2017-1-524-322  2017            1       Clear
# 1  132140    AFG-1989-1-411-2  1989            1       Clear
# 2  130364   AFG-1989-1-411-37  1989            1       Clear
# 3  130359    AFG-1989-1-411-4  1989            1       Clear
# 4  133883   AFG-1989-1-411-39  1989            1       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                 1               259              259
# 1                 1               333              333
# 2                 1               333              333
# 3                 1               333              333
# 4                 1               333              333
#
#              conflict_name  dyad_dset_id  ...   date_end deaths_a  deaths_b  \
# 0         Iraq: Government           524  ... 2017-07-31        0         4
# 1  Afghanistan: Government           724  ... 1989-01-13        6         0
# 2  Afghanistan: Government           724  ... 1989-01-18        0         0
# 3  Afghanistan: Government           724  ... 1989-01-24        0         0
# 4  Afghanistan: Government           724  ... 1989-02-05        0         0
#
#    deaths_civilians deaths_unknown  best  high  low  gwnoa gwnob
# 0                 0              2     6     6    6    645   NaN
# 1                 0              0     6     6    6    700   NaN
# 2                 0              4     4     4    0    700   NaN
# 3                 0            600   600   600  600    700   NaN
# 4                 0              2     2     2    0    700   NaN
#
# [5 rows x 49 columns]

# %%
conflict.columns
# Out:
# Index(['id', 'relid', 'year', 'active_year', 'code_status', 'type_of_violence',
#        'conflict_dset_id', 'conflict_new_id', 'conflict_name', 'dyad_dset_id',
#        'dyad_new_id', 'dyad_name', 'side_a_dset_id', 'side_a_new_id', 'side_a',
#        'side_b_dset_id', 'side_b_new_id', 'side_b', 'number_of_sources',
#        'source_article', 'source_office', 'source_date', 'source_headline',
#        'source_original', 'where_prec', 'where_coordinates',
#        'where_description', 'adm_1', 'adm_2', 'latitude', 'longitude',
#        'geom_wkt', 'priogrid_gid', 'country', 'country_id', 'region',
#        'event_clarity', 'date_prec', 'date_start', 'date_end', 'deaths_a',
#        'deaths_b', 'deaths_civilians', 'deaths_unknown', 'best', 'high', 'low',
#        'gwnoa', 'gwnob'],
#       dtype='object')

# %% [markdown]
# Remove unnecessary columns

# %%
conflict = conflict[['year','country','region','deaths_a',
       'deaths_b', 'deaths_civilians', 'deaths_unknown']]

# %% [markdown]
# Add extra column to sum all the deaths from all the columns, each of the sides of the conflict, civilians and unknowns

# %%
conflict['Total_deaths']=conflict['deaths_a']+conflict['deaths_b']+conflict['deaths_civilians']+conflict['deaths_unknown']

# %%
conflict.describe()
# Out:
#                 year       deaths_a       deaths_b  deaths_civilians  \
# count  225385.000000  225385.000000  225385.000000     225385.000000
# mean     2008.933319       2.105016       2.656854          4.360237
# std         8.236476      63.717796      32.812313        187.360638
# min      1989.000000       0.000000       0.000000          0.000000
# 25%      2004.000000       0.000000       0.000000          0.000000
# 50%      2012.000000       0.000000       0.000000          0.000000
# 75%      2015.000000       1.000000       2.000000          1.000000
# max      2019.000000   14776.000000    9505.000000      40000.000000
#
#        deaths_unknown   Total_deaths
# count   225385.000000  225385.000000
# mean         2.177452      11.299559
# std        124.964213     239.542891
# min          0.000000       0.000000
# 25%          0.000000       1.000000
# 50%          0.000000       2.000000
# 75%          0.000000       5.000000
# max      48183.000000   48183.000000

# %%
conflict.groupby('year').sum()
# Out:
#       deaths_a  deaths_b  deaths_civilians  deaths_unknown  Total_deaths
# year
# 1989     32163     14908              9746            9875         66692
# 1990     55742     10792             11291           17482         95307
# 1991     19811     25628             13646           24498         83583
# 1992      7524     13077             14906           21050         56557
# 1993      7325     11164             10963           26284         55736
# 1994      5579     12068            534273           18942        570862
# 1995      6059     15628             21207           10439         53333
# 1996      8244     11186             40416           11833         71679
# 1997     10736     13251             19210           18163         61360
# 1998      9311     16722             20333           14782         61148
# 1999     20484     16364             15819           46032         98699
# 2000     11852     12011              8396           59042         91301
# 2001      7577      8736              8751            9884         34948
# 2002      7094      9396             13791            8395         38676
# 2003      5389      7154             11965           12143         36651
# 2004      6514     10039              9419            5965         31937
# 2005      3979      6763              5561            3474         19777
# 2006      5283     11139              6002            5146         27570
# 2007      4377     12581              5928            4419         27305
# 2008      5552     14921              6632           10412         37517
# 2009      5747     13376             14892           12818         46833
# 2010      4651     11947              5498            8773         30869
# 2011      6724     11397              9215           11430         38766
# 2012     25785     21572             21206            9655         78218
# 2013     36819     30527             23031            9616         99993
# 2014     42124     47634             27640           26703        144101
# 2015     33054     53057             23400           12837        122348
# 2016     27002     46820             21972           10787        106581
# 2017     20244     39804             24605           13992         98645
# 2018     18238     34504             12659           17919         83320
# 2019     13456     34649             10359           17975         76439

# %%
conflict.groupby('country').sum()
# Out:
#                          year  deaths_a  deaths_b  deaths_civilians  \
# country
# Afghanistan          67649762     42811    138495             27458
# Albania                  7996         0         4                 2
# Algeria               8288869      3380     15034              1991
# Angola                4082424      1286      7670              4093
# Argentina                3986         0         0                86
# ...                       ...       ...       ...               ...
# Uzbekistan              64044       188       174                 7
# Venezuela             1549928         3        40               725
# Yemen (North Yemen)   5296077     10949      7935              4389
# Zambia                  23913         0         0                55
# Zimbabwe (Rhodesia)    132493         0         0               302
#
#                      deaths_unknown  Total_deaths
# country
# Afghanistan                   49180        257944
# Albania                           0             6
# Algeria                         748         21153
# Angola                        20190         33239
# Argentina                         0            86
# ...                             ...           ...
# Uzbekistan                       31           400
# Venezuela                       187           955
# Yemen (North Yemen)            5772         29045
# Zambia                            0            55
# Zimbabwe (Rhodesia)               3           305
#
# [122 rows x 6 columns]

# %%
new_df = conflict.groupby(['country'], sort=True).sum().reset_index()
new_df = new_df.sort_values(by = ['Total_deaths'], ascending=False)
new_df.head(30)
# Out:
#                       country       year  deaths_a  deaths_b  \
# 91                     Rwanda    3927580       936      4496
# 104                     Syria  122433759    141558    103200
# 0                 Afghanistan   67649762     42811    138495
# 35                   Ethiopia    4058137     85320      3415
# 50                       Iraq   15548594     13943     46783
# 29           DR Congo (Zaire)    8566138     10039     12988
# 102                     Sudan    6435626     27945     12033
# 101                 Sri Lanka    9166523     14941     38007
# 81                    Nigeria    9269410      6436     17816
# 47                      India   31448842     11642     25246
# 97                    Somalia   10704336      6193      9690
# 82                   Pakistan   11727737      5268     17412
# 71                     Mexico    7863290       419       467
# 3                      Angola    4082424      1286      7670
# 119       Yemen (North Yemen)    5296077     10949      7935
# 111                    Turkey   10445862      4896     21155
# 25                   Colombia    9377729      6879     13257
# 14         Bosnia-Herzegovina    3715886      3069      3224
# 90      Russia (Soviet Union)    7512049      6643      6591
# 63                    Liberia    1095184      1016       543
# 2                     Algeria    8288869      3380     15034
# 95               Sierra Leone    2986182      2501      5264
# 75            Myanmar (Burma)    5572099      6318      2624
# 34                    Eritrea      87982     13820      5158
# 87                Philippines    7500300      5074     11965
# 112                    Uganda    3340000      1501      9396
# 18                    Burundi    3093486      1451      4680
# 27                      Congo     463844       200       704
# 64                      Libya    2257124      3320      4118
# 22   Central African Republic    2939911       465       593
#
#      deaths_civilians  deaths_unknown  Total_deaths
# 91             536485            1259        543176
# 104             81635           33450        359843
# 0               27458           49180        257944
# 35               4403           85031        178169
# 50              28995           31938        121659
# 29              72429           19403        114859
# 102             24077           29073         93128
# 101             11191            1489         65628
# 81              17328           15452         57032
# 47              13719            6109         56716
# 97               7548           26893         50324
# 82               6143           12996         41819
# 71                597           39527         41010
# 3                4093           20190         33239
# 119              4389            5772         29045
# 111              2170             390         28611
# 25               6181            1419         27736
# 14              14492            5548         26333
# 90               5016            7315         25565
# 63              17853            3833         23245
# 2                1991             748         21153
# 95               9667            3011         20443
# 75               6625            4669         20236
# 34                139             819         19936
# 87               1992             783         19814
# 112              5529             608         17034
# 18               8591            2092         16814
# 27               1639           13100         15643
# 64               1126            4784         13348
# 22               8024            3407         12489

# %%
conflict.groupby('region').sum()
# Out:
#                   year  deaths_a  deaths_b  deaths_civilians  deaths_unknown  \
# region
# Africa        89710983    176092    129654            741460          251672
# Americas      23308317     11780     22211             14872           50586
# Asia         156716406     94446    244004             78901           89977
# Europe        18613298     17499     15863             24946           20601
# Middle East  164434432    174622    187083            122553           77929
#
#              Total_deaths
# region
# Africa            1298878
# Americas            99449
# Asia               507328
# Europe              78909
# Middle East        562187

# %% [markdown]
# # 1 sample hypothesis test

# %% [markdown]
#  H0=mean of deaths in conflict after 2001 in Middle East = 10; H1=mean of deaths in conflict is different than H0

# %%
total_deaths=conflict[['year','region','Total_deaths']]
Middle_East = total_deaths[(total_deaths['region'] == 'Middle East')&(total_deaths['year']>2001)] 
deaths_ME=Middle_East['Total_deaths']
deaths_ME.dropna()
# Out:
# 40470      1
# 40471      1
# 40472      4
# 40473      1
# 40474      1
#           ..
# 225302    10
# 225303     1
# 225304     1
# 225305     0
# 225306     0
# Name: Total_deaths, Length: 75923, dtype: int64

# %%
deaths_ME.max()
deaths_ME.min()
# Out:
# 0

# %%
deaths_ME.mean()
# Out:
# 6.575477786704951

# %%
conflict_mean = deaths_ME.mean()
mu = 10
sample_stdev = deaths_ME.std()
standard_error = sample_stdev / np.sqrt(len(deaths_ME))
t_value = (conflict_mean - mu) / standard_error
print(t_value)
# Out:
# -8.861948076758152

# %%
df = len(deaths_ME) - 1
mean, var, skew, kurt = t.stats(df, moments='mvsk')

# %%
# retrieve value <= probability
alpha = 0.05
alpha = 1 - alpha
alpha = t.ppf(alpha,deaths_ME)
#print(alpha)
# confirm with cdf
t, p = ttest_1samp(deaths_ME,10)
print(t)
print(p)
# Out:
# -8.861948076755104
# 8.028153638710254e-19

# %% [markdown]
# we can be very certain that the null hypothesis can be rejected, so the mean of death in conflict in the Middle East is different than 10

# %% [markdown]
# # 2 sample hypothesis test

# %% [markdown]
#   H0: mean of suicide in the range 1989-2016 in 1 country Europe  = mean of deaths in conflict same timeframe in 1 country Middle East
#   H1: mean of suicide in the range 1989-2016 in 1 country Europe  ≠ mean of deaths in conflict same timeframe in 1 country Middle East

# %% [markdown]
# Selecting one Country in Europe: Germany, one Country in Middle East: Iran, both around 83 mil inhabitants, for this 2 sample hypothesis test

# %%
Germany_suicide = suicides[suicides['country'] == 'Germany'] 
Iran_conflict=conflict[conflict['country'] == 'Iran'] 
Germany_Iran = pd.merge(Germany_suicide, Iran_conflict, on='year', how='right')
Germany_Iran.dropna(how='all',inplace=True)
sp.stats.ttest_ind(Germany_Iran.dropna()['suicides_no'], Germany_Iran.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=33.98783895018233, pvalue=9.616645706764838e-203)

# %%
Germany_Iran['suicides_no'].mean()
# Out:
# 903.510460251046

# %%
Germany_Iran['Total_deaths'].mean()
# Out:
# 5.650169491525424

# %%
sns.displot(Germany_suicide, x='suicides_no')

# %%
sns.displot(Iran_conflict, x='Total_deaths')

# %%
g = sns.JointGrid(data=Germany_Iran, x="suicides_no", y="Total_deaths")
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)

# %% [markdown]
# Our p-value is very small. This means that there is a significant difference between the two sample means.

# %% [markdown]
# We will reject the null hypothesis and conclude that there is a significant difference between the mean of suicides in Germany and the mean of deaths in conflict in Iran

# %%
Netherlands_suicide = suicides[suicides['country'] == 'Netherlands'] 
Syria_conflict=conflict[conflict['country'] == 'Syria'] 
Netherlands_Syria = pd.merge(Netherlands_suicide, Syria_conflict, on='year', how='right')
sp.stats.ttest_ind(Netherlands_Syria.dropna()['suicides_no'], Netherlands_Syria.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=485.3918482190967, pvalue=0.0)

# %%
Netherlands_Syria['suicides_no'].mean()
# Out:
# 156.10923486689364

# %%
Netherlands_Syria['Total_deaths'].mean()
# Out:
# 5.842499472127501

# %%
Poland_suicide = suicides[suicides['country'] == 'Poland'] 
Iraq_conflict=conflict[conflict['country'] == 'Iraq'] 
Poland_Iraq = pd.merge(Poland_suicide, Iraq_conflict, on='year', how='right')
Poland_Iraq.dropna(how='all',inplace=True)
sp.stats.ttest_ind(Poland_Iraq.dropna()['suicides_no'], Poland_Iraq.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %% [markdown]
# # 2 sample hypothesis test

# %% [markdown]
# H0= mean of suicide in the range 1989-2016 in whole region Middle East vs deaths in conflict same timeframe; H1=mean of suicide vs deaths in conflict is higher

# %%
ME_suicide = suicides[suicides['region'] == 'Middle East'] 
ME_conflict = conflict[conflict['region'] == 'Middle East']

# %%
sp.stats.ttest_ind(ME_suicide.dropna()['suicides_no'], ME_conflict.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=3.619582222687617, pvalue=0.0002952560924923878)

# %% [markdown]
# Our p-value is very small, 0.0002. This means that there is a significant difference between the two sample means.
# We will reject the null hypothesis and conclude that there is a significant difference between the mean of suicides in Middle East and the mean of deaths in conflict in Middle East

# %%
ME_suicide['suicides_no'].mean()
# Out:
# 19.11764705882353

# %%
ME_conflict['Total_deaths'].mean()
# Out:
# 6.8805243124824065

# %%
Africa_suicide = suicides[suicides['region'] == 'Africa'] 
Africa_conflict = conflict[conflict['region'] == 'Africa']

# %%
sp.stats.ttest_ind(Africa_suicide.dropna()['suicides_no'], Africa_conflict.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=0.14740491772576403, pvalue=0.882813087397694)

# %%
Africa_suicide['suicides_no'].mean()
# Out:
# 30.504166666666666

# %%
Africa_conflict['Total_deaths'].mean()
# Out:
# 29.042729691657538

# %%
afr_s=Africa_suicide.groupby('year').mean()

# %%
sns.displot(afr_s, x='suicides_no')

# %%
afr=Africa_conflict.groupby('year').mean()

# %%
sns.displot(afr, x='Total_deaths')

# %%
fig, axes = plt.subplots(1, 2)

afr.hist('Total_deaths', bins=7, ax=axes[0])
afr_s.hist('suicides_no', bins=7, ax=axes[1])
axes[0].set_title('Mean of deaths in conflict')
axes[1].set_title('Mean of suicides')
# Out:
# Text(0.5, 1.0, 'Mean of suicides')

# %%
Americas_suicide = suicides[suicides['region'] == 'Americas'] 
Americas_conflict = conflict[conflict['region'] == 'Americas'] 
sp.stats.ttest_ind(Americas_suicide.dropna()['suicides_no'], Americas_conflict.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=42.897096670867406, pvalue=0.0)

# %%
Americas_suicide['suicides_no'].mean()
# Out:
# 145.89771689497718

# %%
Americas_conflict['Total_deaths'].mean()
# Out:
# 8.555488644184447

# %%
Asia_suicide = suicides[suicides['region'] == 'Asia'] 
Asia_conflict = conflict[conflict['region'] == 'Asia'] 
sp.stats.ttest_ind(Asia_suicide.dropna()['suicides_no'], Asia_conflict.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=101.65592583364273, pvalue=0.0)

# %%
Asia_suicide['suicides_no'].mean()
# Out:
# 193.18457648546143

# %%
Asia_conflict['Total_deaths'].mean()
# Out:
# 6.501371197170464

# %%
Europe_suicide = suicides[suicides['region'] == 'Europe'] 
Europe_conflict = conflict[conflict['region'] == 'Europe'] 
sp.stats.ttest_ind(Europe_suicide.dropna()['suicides_no'], Europe_conflict.dropna()['Total_deaths'])
# Out:
# Ttest_indResult(statistic=47.132297544654264, pvalue=0.0)

# %%
Europe_suicide['suicides_no'].mean()
# Out:
# 298.9929145921103

# %%
Europe_conflict['Total_deaths'].mean()
# Out:
# 8.48757663762504

# %%
Europe_suicide['suicides_no'].std()
# Out:
# 568.7536555424845

# %% [markdown]
# # Confidence Intervals

# %%
sample_size = len(Europe_suicide['suicides_no']) 
stdev_Europe = Europe_suicide['suicides_no'].std()
marg_of_error = stdev_Europe / np.sqrt(sample_size)
confidence_level = 0.95
z = stats.norm.interval(confidence_level)[1] 
sample_mean = np.mean(Europe_suicide['suicides_no'])
con_int = [sample_mean - (z * marg_of_error) , (sample_mean + (z * marg_of_error))]
list(con_int)
print(f"With 95% confidence, the true mean for suicide rates in Europe lies within the interval {con_int[0]} and {con_int[1]}.")
# Out:
# With 95% confidence, the true mean for suicide rates in Europe lies within the interval 283.56689572194284 and 314.4189334622778.

# %%
sample_size = len(Africa_conflict['Total_deaths']) 
stdev_Africa = Africa_conflict['Total_deaths'].std()
marg_of_error = stdev_Africa / np.sqrt(sample_size)
confidence_level = 0.95
z = stats.norm.interval(confidence_level)[1] 
sample_mean = np.mean(Africa_conflict['Total_deaths'])
con_int = [sample_mean - (z * marg_of_error) , (sample_mean + (z * marg_of_error))]
list(con_int)
print(f"With 95% confidence, the true mean for deaths in conflict in Africa lies within the interval {con_int[0]} and {con_int[1]}.")
# Out:
# With 95% confidence, the true mean for deaths in conflict in Africa lies within the interval 24.30651975827893 and 33.778939625036145.

# %%
sample_size = len(Africa_suicide['suicides_no']) 
stdev_Africa1 = Africa_suicide['suicides_no'].std()
marg_of_error = stdev_Africa1 / np.sqrt(sample_size)
confidence_level = 0.95
z = stats.norm.interval(confidence_level)[1] 
sample_mean = np.mean(Africa_suicide['suicides_no'])
con_int = [sample_mean - (z * marg_of_error) , (sample_mean + (z * marg_of_error))]
list(con_int)
print(f"With 95% confidence, the true mean for suicides in Africa lies within the interval {con_int[0]} and {con_int[1]}.")
# Out:
# With 95% confidence, the true mean for suicides in Africa lies within the interval 25.925146391295435 and 35.0831869420379.
